# %%
import pandas as pd
# from plotnine import *
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
from sklearn.ensemble import RandomForestRegressor

import statsmodels

# import xgboost as xgb

from statsforecast import StatsForecast
from statsforecast.models import (
    AutoARIMA,
    HoltWinters,
    AutoTheta,
    AutoETS,
    DynamicOptimizedTheta as DOT,
    SeasonalNaive
)


import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white")

# %%
def time_delay_embedding(series: pd.Series, n_lags: int, horizon: int):
    """
    Time delay embedding
    Time series for supervised learning
    :param series: time series as pd.Series
    :param n_lags: number of past values to used as explanatory variables
    :param horizon: how many values to forecast
    :return: pd.DataFrame with reconstructed time series
    """
    assert isinstance(series, pd.Series)

    if series.name is None:
        name = 'Series'
    else:
        name = series.name

    n_lags_iter = list(range(n_lags, -horizon, -1))

    X = [series.shift(i) for i in n_lags_iter]
    X = pd.concat(X, axis=1).dropna()
    X.columns = [f'{name}(t-{j - 1})'
                 if j > 0 else f'{name}(t+{np.abs(j) + 1})'
                 for j in n_lags_iter]

    return X

# %%
series = pd.read_csv("new_england_tavg.csv", index_col=0, parse_dates=True,squeeze=True)
# series2 = series.diff()
series
# Out:
# /tmp/ipykernel_125856/3311675235.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv("new_england_tavg.csv", index_col=0, parse_dates=True,squeeze=True)
# date
# 1951-01-01   -7.01
# 1951-01-02   -6.75
# 1951-01-03   -1.29
# 1951-01-04    4.18
# 1951-01-05   -0.57
#               ...
# 2021-12-27   -2.83
# 2021-12-28   -3.98
# 2021-12-29   -1.90
# 2021-12-30   -1.52
# 2021-12-31    0.49
# Name: measurement, Length: 25933, dtype: float64

# %%
# test how well prior day predicts temp
maxt = pd.read_csv("new_england_tmax.csv", index_col=0, parse_dates=True,squeeze=True)
mint = pd.read_csv("new_england_tmin.csv", index_col=0, parse_dates=True,squeeze=True)
shifted = series.shift(1).fillna(0)
shifted2 = series.shift(2).fillna(0)
shifted3 = series.shift(3).fillna(0)
shifted4 = series.shift(4).fillna(0)
shifted_min = mint.shift(1).fillna(0)
shifted_max = maxt.shift(1).fillna(0)

momentum = shifted - shifted2
x = shifted + (momentum*0.1)
z = shifted.rolling(3).mean().fillna(0)
y = (z+x)/2

mae(series, shifted)
# Out:
# /tmp/ipykernel_125856/1419561211.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   maxt = pd.read_csv("new_england_tmax.csv", index_col=0, parse_dates=True,squeeze=True)
# /tmp/ipykernel_125856/1419561211.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   mint = pd.read_csv("new_england_tmin.csv", index_col=0, parse_dates=True,squeeze=True)
# 2.2901191577973163

# %%
pd.plotting.lag_plot(series, lag=(1))
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
labels = [0,1,7,30,182,365]
correlation = pd.concat([series, series.shift(1), series.shift(7),series.shift(30),series.shift(182),series.shift(365)], axis=1)

correlation = correlation.corr(method = 'pearson')

plt.subplots(figsize=(11, 9))
mask = np.triu(np.ones_like(correlation, dtype=bool))
cmap = sns.diverging_palette(0, 255, sep=2, n=512, as_cmap=True)
sns.heatmap(correlation, mask=mask,cmap=cmap, xticklabels=labels, yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
statsmodels.graphics.tsaplots.plot_acf(series, lags=np.arange(1,1000))

# %%
# applying time delay embedding
# using 3 lags (n_lags=3) to predict the next value (horizon=1)
ts = time_delay_embedding(series=series, n_lags=365, horizon=1)
ts
# Out:
#             measurement(t-364)  measurement(t-363)  measurement(t-362)  \
# date
# 1952-01-01               -7.01               -6.75               -1.29
# 1952-01-02               -6.75               -1.29                4.18
#             measurement(t-0)  measurement(t+1)
# date
# 1952-01-01              0.07             -0.56
# 1952-01-02             -0.56              1.31
# 1952-01-03              1.31             -4.10
# 1952-01-04             -4.10             -9.10
# 1952-01-05             -9.10            -12.22
# ...                      ...               ...
# 2021-12-27             -4.11             -2.83
# 2021-12-28             -2.83             -3.98
# 2021-12-29             -3.98             -1.90
# 2021-12-30             -1.90             -1.52
# 2021-12-31             -1.52              0.49
#
# [25568 rows x 366 columns]

# %%
# splitting target variable from explanatory variables
target_columns = ts.columns.str.contains('\+')
X = ts.iloc[:, ~target_columns]
y = ts['measurement(t+1)']
X
# Out:
#             measurement(t-364)  measurement(t-363)  measurement(t-362)  \
# date
# 1952-01-01               -7.01               -6.75               -1.29
# 1952-01-02               -6.75               -1.29                4.18
# 1952-01-03               -1.29                4.18               -0.57
# 1952-01-04                4.18               -0.57               -6.49
# 1952-01-05               -0.57               -6.49               -7.24
# ...                        ...                 ...                 ...
# 2021-12-27               -2.59               -3.97               -0.09
# 2021-12-28               -3.97               -0.09               -5.66
# 2021-12-29               -0.09               -5.66               -3.70
# 2021-12-30               -5.66               -3.70               -1.95
# 2021-12-31               -3.70               -1.95               -3.38
#
#             measurement(t-361)  measurement(t-360)  measurement(t-359)  \
# date
# 1952-01-01                4.18               -0.57               -6.49
# 1952-01-02               -0.57               -6.49               -7.24
# 1952-01-03               -6.49               -7.24               -9.80
# 1952-01-04               -7.24               -9.80              -11.71
# 1952-01-05               -9.80              -11.71               -9.34
# ...                        ...                 ...                 ...
# 2021-12-27               -5.66               -3.70               -1.95
# 2021-12-28               -3.70               -1.95               -3.38
# 2021-12-29               -1.95               -3.38               -2.89
# 2021-12-30               -3.38               -2.89               -3.79
# 2021-12-31               -2.89               -3.79               -1.74
#
#             measurement(t-358)  measurement(t-357)  measurement(t-356)  \
# date
# 1952-01-01               -7.24               -9.80              -11.71
# 1952-01-02               -9.80              -11.71               -9.34
# 1952-01-03              -11.71               -9.34               -6.10
# 1952-01-04               -9.34               -6.10               -2.96
# 1952-01-05               -6.10               -2.96               -3.86
# ...                        ...                 ...                 ...
# 2021-12-27               -3.38               -2.89               -3.79
# 2021-12-28               -2.89               -3.79               -1.74
# 2021-12-29               -3.79               -1.74               -2.40
# 2021-12-30               -1.74               -2.40               -2.60
# 2021-12-31               -2.40               -2.60               -3.21
#
#             measurement(t-355)  ...  measurement(t-9)  measurement(t-8)  \
# date                            ...
# 1952-01-01               -9.34  ...              1.29             -4.50
# 1952-01-02               -6.10  ...             -4.50             -7.60
# 1952-01-03               -2.96  ...             -7.60            -10.36
# 1952-01-04               -3.86  ...            -10.36             -8.19
# 1952-01-05               -7.59  ...             -8.19            -11.03
# ...                        ...  ...               ...               ...
# 2021-12-27               -1.74  ...              6.34              3.32
# 2021-12-28               -2.40  ...              3.32             -2.09
# 2021-12-29               -2.60  ...             -2.09             -6.88
# 2021-12-30               -3.21  ...             -6.88             -6.86
# 2021-12-31               -4.35  ...             -6.86             -2.20
#
#             measurement(t-7)  measurement(t-6)  measurement(t-5)  \
# date
# 1952-01-01             -7.60            -10.36             -8.19
# 1952-01-02            -10.36             -8.19            -11.03
# 1952-01-03             -8.19            -11.03            -15.80
# 1952-01-04            -11.03            -15.80            -14.57
# 1952-01-05            -15.80            -14.57             -4.55
# ...                      ...               ...               ...
# 2021-12-27             -2.09             -6.88             -6.86
# 2021-12-28             -6.88             -6.86             -2.20
# 2021-12-29             -6.86             -2.20             -3.30
# 2021-12-30             -2.20             -3.30             -9.97
# 2021-12-31             -3.30             -9.97             -8.30
#
#             measurement(t-4)  measurement(t-3)  measurement(t-2)  \
# date
# 1952-01-01            -11.03            -15.80            -14.57
# 1952-01-02            -15.80            -14.57             -4.55
# 1952-01-03            -14.57             -4.55              0.07
# 1952-01-04             -4.55              0.07             -0.56
# 1952-01-05              0.07             -0.56              1.31
# ...                      ...               ...               ...
# 2021-12-27             -2.20             -3.30             -9.97
# 2021-12-28             -3.30             -9.97             -8.30
# 2021-12-29             -9.97             -8.30             -4.11
# 2021-12-30             -8.30             -4.11             -2.83
# 2021-12-31             -4.11             -2.83             -3.98
#
#             measurement(t-1)  measurement(t-0)
# date
# 1952-01-01             -4.55              0.07
# 1952-01-02              0.07             -0.56
# 1952-01-03             -0.56              1.31
# 1952-01-04              1.31             -4.10
# 1952-01-05             -4.10             -9.10
# ...                      ...               ...
# 2021-12-27             -8.30             -4.11
# 2021-12-28             -4.11             -2.83
# 2021-12-29             -2.83             -3.98
# 2021-12-30             -3.98             -1.90
# 2021-12-31             -1.90             -1.52
#
# [25568 rows x 365 columns]

# %%
# train/test split
X_tr, X_ts, y_tr, y_ts = train_test_split(X, y, test_size=0.33, shuffle=False)

# %%
# fitting a random forest
model = RandomForestRegressor(verbose=1)
model.fit(X_tr, y_tr)
model
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  5.6min finished
# RandomForestRegressor(verbose=1)

# %%
# getting forecasts for the test set
predictions = model.predict(X_ts)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
# computing MAE error
mae(y_ts, predictions)
# Out:
# 2.0932675515525005

# %%
# df = pd.read_csv("new_england_tavg.csv")
# arima = StatsForecast(
#     models = [AutoARIMA(season_length = 365)],freq = 'D')

# arima.fit(df)
# sf.predict(h=12, level=[95])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_124678/3173885090.py in <module>
#       3     models = [AutoARIMA(season_length = 365)],freq = 'D')
#       4
# ----> 5 arima.fit(df)
#       6 sf.predict(h=12, level=[95])
#
# ~/.local/lib/python3.10/site-packages/statsforecast/core.py in fit(self, df, sort_df)
#     531         `self`: Returns with stored `StatsForecast` fitted `models`.
#     532         """
# --> 533         self._prepare_fit(df, sort_df)
#     534         if self.n_jobs == 1:
#     535             self.fitted_ = self.ga.fit(models=self.models)
#
# ~/.local/lib/python3.10/site-packages/statsforecast/core.py in _prepare_fit(self, df, sort_df)
#     510         if df is not None:
#     511             if df.index.name != "unique_id":
# --> 512                 df = df.set_index("unique_id")
#     513             df = _parse_ds_type(df)
#     514             self.ga, self.uids, self.last_dates, self.ds = _grouped_array_from_df(
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6007
#    6008         if missing:
# -> 6009             raise KeyError(f"None of {missing} are in the columns")
#    6010
#    6011         if inplace:
#
# KeyError: "None of ['unique_id'] are in the columns"

# %%
# data = df
# #set frquency of index to daily
# data.index.freq = 'D'
# myorder = (1,1,1)
# myseasonal_order = (1,1,1,365)
# # add frequency parameter to SARIMAX
# model = SARIMAX(data, order=myorder, seasonal_order=myseasonal_order, freq="D")
# results = model.fit()
# print(results.summary())



# rom prophet import Prophet
# df["ds"] = df.index
# df["y"] = df["measurement"]
# df = df[["ds", "y"]]
# m = Prophet()
# m.fit(df)
# future = m.make_future_dataframe(periods=365)
# forecast = m.predict(future)
# fig1 = m.plot(forecast)
# fig2 = m.plot_components(forecast)
# plt.show()
# m.
